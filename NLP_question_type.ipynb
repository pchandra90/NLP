# %%
import sys
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from colorama import Fore, Back
from nltk.corpus import wordnet as wn
from nltk.corpus import wordnet_ic
semcor_ic = wordnet_ic.ic('ic-semcor.dat')
person = wn.synset('person.n.01')
place = wn.synset('place.n.01')
time = wn.synset('time.n.01')
month = wn.synset('month.n.01')
year = wn.synset('year.n.01')
day = wn.synset('day.n.01')
date = wn.synset('date.n.01')

from nltk.corpus import stopwords
stopwords = stopwords.words('english')
stopwords.append("'s")

# %%
AV = ['is', 'am', 'are', 'can', 'cannot', 'could', "couldn't", 'dare', 'may', 'might', 'must', 
      'need', 'ought', 'shall', 'should', "shouldn't", 'will', 'would', "won't", "wouldn't", 
      "don't", "doesn't", "hasn't", "haven't"]

AVE = ['do', 'does']
AVH = ['has', 'have']

WHAT = ['what', 'which']
WHEN = ['when']
WHO = ['who', 'whom', 'whose']

# %%
def time_similarity(word):
    return max(time.lin_similarity(word, semcor_ic), 
              month.lin_similarity(word, semcor_ic),
              year.lin_similarity(word, semcor_ic), 
              day.lin_similarity(word, semcor_ic), 
              date.lin_similarity(word, semcor_ic))

# %%
def my_tag_pos(list):
    tagged_list = []   
    for i in range(len(list)):
        word = list[i]
        if word.lower() in WHAT:
            tagged_list.append((word, 'WHAT'))
        elif word.lower() in WHEN:
            tagged_list.append((word, 'WHEN'))
        elif word.lower() in WHO:
            tagged_list.append((word, 'WHO'))
        elif word.lower() in AV:
            tagged_list.append((word, 'AV'))
        elif word.lower() in AVE and (i == 0 or list[i-1] == ',' 
                                      or nltk.pos_tag([list[i-1]])[0][1][0] == 'W'):
            tagged_list.append((word, 'AV'))
        elif word.lower() in AVH and (i == 0 or list[i-1] == ',' 
                                      or nltk.pos_tag([list[i-1]])[0][1][0] == 'W'):
            tagged_list.append((word, 'AV'))
        else:
            tagged_list.append((word, 'NULL'))
    
    return tagged_list

# %%
def tag_pos(sent_qus):
    words = word_tokenize(sent_qus)
    tag_pos_my_tag = my_tag_pos(words)
    tag_pos_nltk_tag = nltk.pos_tag(words)
    tagged = []
    for i in range(len(tag_pos_my_tag)):
        word, tag = tag_pos_my_tag[i]
        if tag == 'NULL':
            tag = tag_pos_nltk_tag[i][1]
        tagged.append((word, tag))
            
    return tagged

# %%
def find_type(ques_sent):
    tagged_list = tag_pos(ques_sent)
    word_token = word_tokenize(ques_sent)
    dict_type = {'Affirmation': False, 'What': False, 'When': False, 'Who': False}
    i = 0
    while i < len(word_token):
        if tagged_list[i][1] is 'AV':
            if 'or' not in word_token:
                dict_type['Affirmation'] = True
                break
            elif 'any' in word_token or 'either' in word_token:
                dict_type['Affirmation'] = True
                break
            else:
                dict_type['What'] = True
                break
        
        elif tagged_list[i][1] is 'WHO':
            dict_type['Who'] = True
            break
        
        elif tagged_list[i][1] is 'WHEN':
            dict_type['When'] = True
            break
        
        elif tagged_list[i][1] is 'WHAT':
            if 'location' in ques_sent.lower() or 'place' in ques_sent.lower():
                break
            elif 'time' in ques_sent.lower() or 'date' in ques_sent.lower():
                dict_type['When'] = True
                break
            elif 'the name of' in ques_sent.lower() or 'the names of' in ques_sent.lower():
                words_without_stopwords = [w for w in word_token if w.lower() not in stopwords]
                tagged_without_stopwords = nltk.pos_tag(words_without_stopwords)
                try:
                    j = words_without_stopwords.index('name')+1
                except:
                    #print(Fore.GREEN + str(tagged_without_stopwords) + Fore.RESET)
                    j = words_without_stopwords.index('names')+1 
                while j < len(words_without_stopwords):
                    if tagged_without_stopwords[j][1][:2] == 'NN':
                        word_noun = tagged_without_stopwords[j][0]
                        break
                    j+=1
                
                try:
                    ti = word_token.index(word_noun)
                    if((ti+1) < len(word_token) and word_token[ti+1] in WHO):
                        dict_type['Who'] = True
                        break
                        
                    word_noun = wn.synsets(word_noun)[0]
                    person_s = person.lin_similarity(word_noun, semcor_ic)
                    place_s = place.lin_similarity(word_noun, semcor_ic)
                    if (person_s > place_s) and person_s > 0.2:
                        dict_type['Who'] = True
                        break
                    else:
                        dict_type['What'] = True
                        break
                        
                except:
                    #print(Fore.YELLOW + str(word_noun) + Fore.RESET)
                    dict_type['What'] = True
                    break
                    
            elif ((i+2) < len(tagged_list)) and tagged_list[i+1][1][:2] == 'NN'and tagged_list[i+2][1][:2] == 'VB':
                word_noun = tagged_list[i+1][0]
                try:
                    word_noun = wn.synsets(word_noun)[0]
                    person_s = person.lin_similarity(word_noun, semcor_ic)
                    time_s = time_similarity(word_noun)
                    if person_s >= 0.2:
                        dict_type['Who'] = True
                        break
                    elif time_s >= 0.2:
                        dict_type['When'] = True
                        break
                    else:
                        dict_type['What'] = True
                        break 
                        
                except:
                    #print(Fore.RED + str(word_noun) + Fore.RESET)
                    dict_type['What'] = True
                    break
                    
            else:
                dict_type['What'] = True
                break
                
        elif i >= (len(word_token) -1):
            break
        
        else:
            for k in range(i+1,len(word_token)):
                if tagged_list[k][1] == 'WHAT':
                    i = k
                    break
                elif tagged_list[k][1] == 'WHO':
                    i = k
                    break
                elif tagged_list[k][1] == 'WHEN':
                    i = k
                    break
                elif tagged_list[k][1] == ',':
                    i = k+1
                    break
                elif k+1 >= len(word_token):
                    i = k+1
                
            
    return dict_type

# %%
file = input("Enter the name of questions file (.txt format): ")
index = file.find('.txt', -4)
if index == -1:
    file = file + '.txt'
try:
    questions = open(file, 'r').read()
except:
    print(file + ' not found. exittng...')
    sys.exit()

ques_list = sent_tokenize(questions)
print('Nos. of questions: {0}'.format(len(ques_list)) )
total_printed = 0
FROM = 0
TO = len(ques_list)
for q in range(FROM, TO):
    dict_type = find_type(ques_list[q])
    if dict_type['Affirmation'] is True:
        print(Fore.GREEN + ques_list[q] + ' Type: ' + 'Affirmation' + Fore.RESET )
        total_printed+=1
    elif dict_type['What'] is True:
        print(Fore.CYAN + ques_list[q] + ' Type: ' + 'What' + Fore.RESET )
        total_printed+=1
    elif dict_type['When'] is True:
        print(Fore.BLUE + ques_list[q] + ' Type: ' + 'When' + Fore.RESET )
        total_printed+=1
    elif dict_type['Who'] is True:
        print(Fore.MAGENTA + ques_list[q] + ' Type: ' + 'Who' + Fore.RESET )
        total_printed+=1
    else:
        print(Fore.RED + ques_list[q] + ' Type: ' + 'Unknown' + Fore.RESET )
        total_printed+=1
        
    
    
print('Total printed: {0}'.format(total_printed))
# Out:
# Enter the name of questions file (.txt format): question_type.txt
# Nos. of questions: 174
# What color is the red sea? Type: What
# WHAT IS THE CAPITAL OF FRANCE? Type: What
# What is a bot? Type: What
# What is the color of the sky? Type: What
# What is a cigar made out of? Type: What
# What is the capital of Spain? Type: What
# What is the first book of the bible? Type: What
# What is snow? Type: What
# What is bigger a dog or an elephant? Type: What
# What is the location of the Eiffel Tower? Type: Unknown
# What is YouTube? Type: What
# What's the name of the computer who recently competed on Jeopardy? Type: Who
# What month of the year is this? Type: What
# What is the last month of the year? Type: What
# Madrid is the capital of what country? Type: What
# Milk comes from what animal? Type: What
# Do you know what DVD stands for? Type: Affirmation
# Who is on a dollar bill? Type: Who
# Who is George Bush? Type: Who
# Who is Albert Einstein? Type: Who
# Do u know who Elvis Presley is? Type: Affirmation
# Who wrote the Bible? Type: Who
# Do you know who wrote the Lord of the Rings books? Type: Affirmation
# Do you know how far away the Sun is? Type: Affirmation
# How many days are there in a leap year? Type: Unknown
# How many stars are there? Type: Unknown
# How many fingers does a human have? Type: Unknown
# How many days in a year? Type: Unknown
# How many sides are there on an octagon? Type: Unknown
# Can you name two of Earthâ€™s oceans? Type: Affirmation
# Do you think a tomato is a fruit or a vegetable? Type: What
# How do you eat? Type: Unknown
# Is snow cold? Type: Affirmation
# When do birds fly south? Type: When
# When was Y2k? Type: When
# WHEN DID THE FIRST MAN WALK ON THE MOON? Type: When
# When does sunset occur? Type: When
# Which is closer the moon or the sun? Type: What
# Where is Earth? Type: Unknown
# Where is Moscow located? Type: Unknown
# Can you tell me the name of a famous actor? Type: Affirmation
# Is the capital of Italy Milan? Type: Affirmation
# Is it possible to prove a negative? Type: Affirmation
# HOW CAN I MAKE A CHATTERBOT? Type: Unknown
# What is a calendar? Type: What
# How many letters are in the alphabet? Type: Unknown
# What should you do before crossing a street? Type: What
# What color do you get when you mix red and yellow? Type: What
# What is tomorrow's date? Type: When
# What language r we speaking? Type: What
# When should I plant flowers, in the spring or in winter? Type: When
# Who should I talk to if I have an emotional problem? Type: Who
# Who created the universe? Type: Who
# Name something you would find on a beach. Type: Unknown
# Name something you would find at the North Pole. Type: Unknown
# Can you name a famous person who passed away in the last 5 years? Type: Affirmation
# Why are robots better than humans? Type: Unknown
# Can you give me an example of a living animal? Type: Affirmation
# How is the weather? Type: Unknown
# Is it winter, spring, summer or fall where you live? Type: What
# What would I do with a knife? Type: What
# How old are you? Type: Unknown
# Are you male or female? Type: What
# Are you a bot? Type: Affirmation
# Which do you like better chocolate or vanilla? Type: What
# WHERE ARE YOU? Type: Unknown
# DO YOU LIKE TALKING TO PEOPLE? Type: Affirmation
# CAN YOU TELL JOKES? Type: Affirmation
# Where are you anyway? Type: Unknown
# Do you like Jazz music? Type: Affirmation
# Are you married? Type: Affirmation
# Who is your botmaster? Type: Who
# What is your favorite color? Type: What
# What is your favorite brand of computer? Type: What
# What is your favorite drink? Type: What
# What is your name? Type: What
# What do you enjoy? Type: What
# What do you hate? Type: What
# What country are you from? Type: What
# What color are your eyes? Type: What
# What is your zodiac sign? Type: What
# What is ur religion? Type: What
# ARE YOU NERVOUS? Type: Affirmation
# Who are you? Type: Who
# Where do you call home? Type: Unknown
# Where were you born? Type: Unknown
# How's life? Type: Unknown
# Who is your best friend? Type: Who
# Where does your botmaster live? Type: Unknown
# Who are you? Type: Who
# Who is your hero? Type: Who
# If you could be any animal, what would you be? Type: What
# When were you born or created? Type: When
# Are you left-handed or right-handed? Type: What
# Are you homosexual, heterosexual, asexual, or bisexual? Type: What
# Would you mind if I called you Al? Type: Affirmation
# So Al when is ur birthday? Type: When
# Do you have a significant other? Type: Affirmation
# My name is Bill. Type: Unknown
# What is your name? Type: What
# Do you have any brothers or sisters? Type: Affirmation
# What is your favorite food? Type: What
# Are you a human or a computer? Type: What
# What's your favorite color? Type: What
# WHO IS YOUR FAVORITE STAR WARS CHARACTER? Type: Who
# WHAT DO YOU THINK ABOUT GEORGE BUSH? Type: What
# What actress do you think is the prettiest? Type: Who
# What do you like to chat about the most? Type: What
# What do you want out of life? Type: What
# What do you think the world will be like in 20 years? Type: What
# What's the last dream u remember having? Type: What
# What do you think is your biggest weakness? Type: What
# What are you planning to do today? Type: What
# So what did you get for Christmas? Type: What
# What kinds of things do you know? Type: What
# Have you entered any contests? Type: Affirmation
# Wouldn't you rather be human? Type: Affirmation
# Do you believe in ghosts? Type: Affirmation
# When do you normally go to bed? Type: When
# Describe your feelings to me. Type: Unknown
# How does your brain work? Type: Unknown
# Who is your favorite character in The Wizard of Oz? Type: Who
# How many questions do people normally ask you every day? Type: Unknown
# Got any plans for the rest of the day? Type: Unknown
# Do you play any musical instruments? Type: Affirmation
# Have you ever been to Mexico? Type: Affirmation
# Do you believe in Santa Claus? Type: Affirmation
# Are you going on vacation this year? Type: Affirmation
# Approximately how far is the nearest gas station from you? Type: Unknown
# What time do you go to bed at night? Type: When
# Do you prefer cats or dogs? Type: What
# Have you read a good book lately? Type: Affirmation
# How is it going? Type: Unknown
# How are you doing? Type: Unknown
# What is 1+1? Type: What
# What is 5 plus ten? Type: What
# What is 18 + 21 + 3? Type: What
# What is ten plus fourteen plus eighty one? Type: What
# What is half of 8? Type: What
# What number comes before three? Type: What
# What number comes after twelve? Type: What
# If I was born on February 23, 1980 how old am I? Type: Unknown
# Which is larger, a pineapple or a pine tree? Type: What
# John is taller than Mary and Mary is taller than Sue. Type: Unknown
# Who is shorter, John or Sue? Type: Who
# What is my name? Type: What
# My friend Bob likes to play tennis. Type: Unknown
# What game does Bob like to play? Type: When
# The ball was hit by Bill. Type: Unknown
# What did Bill hit? Type: What
# Who hit the ball? Type: Who
# What is the name of my friend who likes to play tennis? Type: Who
# What is the date? Type: When
# What season is it? Type: What
# What day of the week is it? Type: What
# What will be tomorrowâ€™s date? Type: When
# What time is it? Type: When
# What is the opposite of indoors? Type: What
# What is the opposite of fast? Type: What
# What is the last letter of the alphabet? Type: What
# What rhymes with inn? Type: What
# What word rhymes with cat? Type: What
# How many is 1,000,000? Type: Unknown
# CAN I HAVE A PICTURE OF YOU? Type: Affirmation
# What is the best nation in the world? Type: What
# Will you teach me something? Type: Affirmation
# May I tell you a joke? Type: Affirmation
# What were we talking about? Type: What
# Why do some people think that artificial intelligence is so interesting? Type: Unknown
# If you were me, would you ask a follow up question? Type: Affirmation
# What do you think it would be like to be human? Type: What
# Y did the chicken cross the road? Type: Unknown
# What sound does a dead cat make? Type: What
# Who will win the 2011 Chatterbox Challenge? Type: Who
# Total printed: 174
